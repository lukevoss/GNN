# %%
import matplotlib.pyplot as plt

from datasets import SuperresolutionMNIST

# %%
train_data = SuperresolutionMNIST(train=True)

image, small_image, label = train_data[0]
plt.imshow(image[0])

# %%
plt.imshow(small_image[0])
